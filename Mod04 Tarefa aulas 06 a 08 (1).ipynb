# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'

# %%
r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
data_json = r.json()

# %%
print(data_json['items'])
# Out:
# [{'id_pleito': 10297, 'tipo_interessado': 'Estado', 'interessado': 'Goiás', 'cod_ibge': 52, 'uf': 'GO', 'num_pvl': None, 'status': 'Arquivado por decurso de prazo', 'num_processo': '17944.001164/2010-87', 'data_protocolo': '2012-09-11T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'PMAE', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco Nacional de Desenvolvimento Econômico e Social', 'moeda': 'Real', 'valor': 12000000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '06/02/2013'}, {'id_pleito': 10315, 'tipo_interessado': 'Município', 'interessado': 'Rio de Janeiro', 'cod_ibge': 3304557, 'uf': 'RJ', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.001169/2005-42', 'data_protocolo': '2007-04-30T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'RELUZ', 'tipo_credor': 'Empresa Não Estatal', 'credor': 'Light - Serviços de Eletricidade S/A', 'moeda': 'Real', 'valor': 30061939.64, 'pvl_asso
# ...

# %%
pd.DataFrame(data_json['items'])
# Out:
#       id_pleito tipo_interessado      interessado  cod_ibge  uf num_pvl  \
# 0         10297           Estado            Goiás        52  GO    None
# 1         10315        Município   Rio de Janeiro   3304557  RJ    None
# 2         12391        Município     Rondonópolis   5107602  MT    None
# 3         11182        Município        Taquarana   2709103  AL    None
# 4         11194        Município  Antônio Cardoso   2901700  BA    None
# ...         ...              ...              ...       ...  ..     ...
# 4995      18605        Município           Ibicuí   2912301  BA    None
# 4996       6765        Município         Louveira   3527306  SP    None
# 4997       6366        Município          Curvelo   3120904  MG    None
# 4998       6539        Município         Ourinhos   3534708  SP    None
# 4999      11185        Município            Irecê   2914604  BA    None
#
#                               status          num_processo  \
# ...

# %%
# 1) Seu código aqui
response = requests.get(url)
data = response.json()
df = pd.DataFrame(data['items'])
df_rj = df[df['interessado'] == 'Rio de Janeiro']
print(df_rj)
# Out:
#       id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 1         10315        Município  Rio de Janeiro   3304557  RJ
# 126        4924        Município  Rio de Janeiro   3304557  RJ
# 250       11692        Município  Rio de Janeiro   3304557  RJ
# 702       13579        Município  Rio de Janeiro   3304557  RJ
# 2030       7085           Estado  Rio de Janeiro        33  RJ
# 2071       5275        Município  Rio de Janeiro   3304557  RJ
# 2208      13584        Município  Rio de Janeiro   3304557  RJ
# 2218       5516           Estado  Rio de Janeiro        33  RJ
# 2390      13624           Estado  Rio de Janeiro        33  RJ
# 2473       9750           Estado  Rio de Janeiro        33  RJ
# 2622       6981        Município  Rio de Janeiro   3304557  RJ
# 2828       8556           Estado  Rio de Janeiro        33  RJ
# 2871       7080           Estado  Rio de Janeiro        33  RJ
# 3030      13574        Município  Rio de Janeiro   3304557  RJ
# ...

# %%
# 2) Seu código aqui
status_counts = df['status'].value_counts()
print(status_counts.head(3))
# Out:
# status
# Deferido             2429
# Deferido (PVL-IF)    1312
# Arquivado             361
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
df['ano_status'] = df['data_status'].str.slice(0, 4)

# %%
# 4. Indique a frequência de cada ano do campo construído no item (3)
ano_counts = df['ano_status'].value_counts()
print(ano_counts)
# Out:
# ano_status
# 30/0    222
# 28/0    192
# 29/0    175
# 27/0    161
# 15/0    157
#        ...
# 25/1     31
# 24/1     28
# 19/1     27
# 02/1     26
# 31/1     23
# Name: count, Length: 62, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
import pandas as pd
import requests

def filtro_uf_tipo(uf, tipo_interessado):
    response = requests.get('https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl')
    data = response.json()
    df = pd.DataFrame(data['items'])

    #filtro
    filtro = (df['uf'] == uf) & (df['tipo_interessado'] == tipo_interessado)
    df_filtrado = df[filtro]
    return df_filtrado

# %%
# 2) Seu código aqui

uf ='MG'
tipo_interessado = 'Estado'

df_mg = filtro_uf_tipo(uf, tipo_interessado)
df_arquivado = df_mg[df_mg['status'] == 'Arquivado por decurso de prazo']
df_arquivado
# Out:
# Empty DataFrame
# Columns: [id_pleito, tipo_interessado, interessado, cod_ibge, uf, num_pvl, status, num_processo, data_protocolo, tipo_operacao, finalidade, tipo_credor, credor, moeda, valor, pvl_assoc_divida, pvl_contradado_credor, data_status]
# Index: []

# %%
# 3) Seu código aqui

uf = 'BA'
tipo_interessado = 'Município'

df_ba = consulta_pvl(uf, tipo_interessado)
deferidas_ba = df_ba[df_ba['status'] == 'Deferido']
municipio_mais_deferidas = deferidas_ba['interessado'].value_counts().idxmax()

print(f"Município da Bahia com mais solicitações deferidas: {municipio_mais_deferidas}")
# Out:
# Município da Bahia com mais solicitações deferidas: Alagoinhas

# %%
# 4) Seu código aqui

df_estado_ba = consulta_pvl('BA', 'Estado')
df_estado_ba.to_csv('solicitacoes_bahia_estado.csv', index=False)

print("Arquivo CSV salvo com sucesso.")
# Out:
# Arquivo CSV salvo com sucesso.
