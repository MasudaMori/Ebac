# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'

# %%
r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
df = r.json()

# %%
print(df['items'])
# Out:
# [{'id_pleito': 12282, 'tipo_interessado': 'Município', 'interessado': 'Córrego Fundo', 'cod_ibge': 3119955, 'uf': 'MG', 'num_pvl': None, 'status': 'Arquivado por decurso de prazo', 'num_processo': '17944.001648/2011-15', 'data_protocolo': '2012-04-16T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco de Desenvolvimento de Minas Gerais S/A', 'moeda': 'Real', 'valor': 1400000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '21/05/2012'}, {'id_pleito': 7934, 'tipo_interessado': 'Município', 'interessado': 'Pedreira', 'cod_ibge': 3537107, 'uf': 'SP', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.000680/2007-99', 'data_protocolo': '2007-06-13T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Saneamento para Todos', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 4200000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '22/06/2007'}, {'id_pleito': 7943, 'tipo_interessado': 'Município', 'interessado': 'Apiaí', 'cod_ibge': 3502705, 'uf': 'SP', 'num_pvl': None, 'status': 'Arquivado', 'num_processo': '17944.000682/2004-35', 'data_protocolo': '2004-06-16T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'PMAT', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Brasil S/A', 'moeda': 'Real', 'valor': 483258, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '22/12/2004'}, {'id_pleito': 8530, 'tipo_interessado': 'Município', 'interessado': 'São Lourenço do Oeste', 'cod_ibge': 4216909, 'uf': 'SC', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.000793/2012-51', 'data_protocolo': '2012-05-28T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Agência de Fomento do Estado de Santa Catarina S/A', 'moeda': 'Real', 'valor': 2300000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '05/07/2012'}, {'id_pleito': 8196, 'tipo_interessado': 'Município', 'interessado': 'Itapeva', 'cod_ibge': 3133600, 'uf': 'MG', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.000732/2010-22', 'data_protocolo': '2010-05-31T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Aquisição de máquinas, equipamentos e veículos', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco de Desenvolvimento de Minas Gerais S/A', 'moeda': 'Real', 'valor': 700000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '23/06/2010'}, {'id_pleito': 8240, 'tipo_interessado': 'Município', 'interessado': 'Rio Brilhante', 'cod_ibge': 5007208, 'uf': 'MS', 'num_pvl': None, 'status': 'Regularizado', 'num_processo': '17944.000739/2011-25', 'data_protocolo': '2012-05-24T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Regularização de Dívida - Energia Elétrica', 'tipo_credor': 'Empresa Não Estatal', 'credor': 'Empresa Energética de Mato Grosso do Sul', 'moeda': 'Real', 'valor': 184294.8, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '11/06/2012'}, {'id_pleito': 8309, 'tipo_interessado': 'Estado', 'interessado': 'Pará', 'cod_ibge': 15, 'uf': 'PA', 'num_pvl': None, 'status': 'Arquivado por decurso de prazo', 'num_processo': '17944.000753/2010-48', 'data_protocolo': '2010-05-28T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Brasil S/A', 'moeda': 'Real', 'valor': 7939000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '21/12/2011'}, {'id_pleito': 8381, 'tipo_interessado': 'Município', 'interessado': 'Palmas', 'cod_ibge': 1721000, 'uf': 'TO', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.000767/2007-66', 'data_proto ...

# %%
pd.DataFrame(df['items'])
# Out:
#       id_pleito tipo_interessado            interessado  cod_ibge  uf num_pvl  \
# 0         12282        Município          Córrego Fundo   3119955  MG    None
# 1          7934        Município               Pedreira   3537107  SP    None
# 2          7943        Município                  Apiaí   3502705  SP    None
# 3          8530        Município  São Lourenço do Oeste   4216909  SC    None
# 4          8196        Município                Itapeva   3133600  MG    None
# ...         ...              ...                    ...       ...  ..     ...
# 4995      17394        Município                 Palmas   4117602  PR    None
# 4996      17888        Município        Alvorada do Sul   4100806  PR    None
# 4997      17896        Município                Selbach   4320305  RS    None
# 4998      17899        Município             Palmitinho   4313805  RS    None
# 4999      17905        Município                 Gaspar   4205902  SC    None
#
#                               status          num_processo  \
# 0     Arquivado por decurso de prazo  17944.001648/2011-15
# 1                           Deferido  17944.000680/2007-99
# 2                          Arquivado  17944.000682/2004-35
# 3                           Deferido  17944.000793/2012-51
# 4                           Deferido  17944.000732/2010-22
# ...                              ...                   ...
# 4995                        Deferido  19406.000470/2007-13
# 4996                        Deferido  19406.000597/2006-51
# 4997                        Deferido  19406.000599/2008-11
# 4998                        Deferido  19406.000600/2008-07
# 4999                       Arquivado  19406.000602/2008-98
#
#             data_protocolo                tipo_operacao  \
# 0     2012-04-16T03:00:00Z  Operação contratual interna
# 1     2007-06-13T03:00:00Z  Operação contratual interna
# 2     2004-06-16T03:00:00Z  Operação contratual interna
# 3     2012-05-28T03:00:00Z  Operação contratual interna
# 4     2010-05-31T03:00:00Z  Operação contratual interna
# ...                    ...                          ...
# 4995  2007-11-28T02:00:00Z  Operação contratual interna
# 4996  2006-08-31T03:00:00Z  Operação contratual interna
# 4997  2008-06-09T03:00:00Z  Operação contratual interna
# 4998  2008-06-09T03:00:00Z  Operação contratual interna
# 4999  2010-02-19T02:00:00Z  Operação contratual interna
#
#                                           finalidade  \
# 0                                     Infraestrutura
# 1                              Saneamento para Todos
# 2                                               PMAT
# 3                                     Infraestrutura
# 4     Aquisição de máquinas, equipamentos e veículos
# ...                                              ...
# 4995                                  Infraestrutura
# 4996                                  Infraestrutura
# 4997                             Caminho da Escola 4
# 4998                             Caminho da Escola 4
# 4999                                  Infraestrutura
#
#                           tipo_credor  \
# 0     Instituição Financeira Nacional
# 1     Instituição Financeira Nacional
# 2     Instituição Financeira Nacional
# 3     Instituição Financeira Nacional
# 4     Instituição Financeira Nacional
# ...                               ...
# 4995  Instituição Financeira Nacional
# 4996  Instituição Financeira Nacional
# 4997  Instituição Financeira Nacional
# 4998  Instituição Financeira Nacional
# 4999  Instituição Financeira Nacional
#
#                                                  credor moeda      valor  \
# 0          Banco de Desenvolvimento de Minas Gerais S/A  Real  1400000.0
# 1                               Caixa Econômica Federal  Real  4200000.0
# 2                                   Banco do Brasil S/A  Real   483258.0
# 3     Agência de Fomento do Estado de Santa Catarina...  Real  2300000.0
# 4          Banco de Desenvolvimento de Minas Gerais S/A  Real   700000.0
# ...                                                 ...   ...        ...
# 4995                   Agência de Fomento do Paraná S/A  Real  1232800.0
# 4996                   Agência de Fomento do Paraná S/A  Real  1350000.0
# 4997                                Banco do Brasil S/A  Real   126750.0
# 4998                                Banco do Brasil S/A  Real   299450.0
# 4999  Agência de Fomento do Estado de Santa Catarina...  Real  1300000.0
#
#       pvl_assoc_divida  pvl_contradado_credor data_status
# 0                    0                      0  21/05/2012
# 1                    0                      0  22/06/2007
# 2                    0                      0  22/12/2004
# 3                    1                      0  05/07/2012
# 4                    1                      0  23/06/2010
# ...                ...                    ...         ...
# 4995                 1                      0  10/12/2007
# 4996                 1                      0  27/09/2006
# 4997                 1                      0  18/06/2008
# 4998                 1                      0  20/06/2008
# 4999                 0                      0  22/02/2010
#
# [5000 rows x 18 columns]

# %%
pd.DataFrame(df['items']).head()
# Out:
#    id_pleito tipo_interessado            interessado  cod_ibge  uf num_pvl  \
# 0      12282        Município          Córrego Fundo   3119955  MG    None
# 1       7934        Município               Pedreira   3537107  SP    None
# 2       7943        Município                  Apiaí   3502705  SP    None
# 3       8530        Município  São Lourenço do Oeste   4216909  SC    None
# 4       8196        Município                Itapeva   3133600  MG    None
#
#                            status          num_processo        data_protocolo  \
# 0  Arquivado por decurso de prazo  17944.001648/2011-15  2012-04-16T03:00:00Z
# 1                        Deferido  17944.000680/2007-99  2007-06-13T03:00:00Z
# 2                       Arquivado  17944.000682/2004-35  2004-06-16T03:00:00Z
# 3                        Deferido  17944.000793/2012-51  2012-05-28T03:00:00Z
# 4                        Deferido  17944.000732/2010-22  2010-05-31T03:00:00Z
#
#                  tipo_operacao  \
# 0  Operação contratual interna
# 1  Operação contratual interna
# 2  Operação contratual interna
# 3  Operação contratual interna
# 4  Operação contratual interna
#
#                                        finalidade  \
# 0                                  Infraestrutura
# 1                           Saneamento para Todos
# 2                                            PMAT
# 3                                  Infraestrutura
# 4  Aquisição de máquinas, equipamentos e veículos
#
#                        tipo_credor  \
# 0  Instituição Financeira Nacional
# 1  Instituição Financeira Nacional
# 2  Instituição Financeira Nacional
# 3  Instituição Financeira Nacional
# 4  Instituição Financeira Nacional
#
#                                               credor moeda      valor  \
# 0       Banco de Desenvolvimento de Minas Gerais S/A  Real  1400000.0
# 1                            Caixa Econômica Federal  Real  4200000.0
# 2                                Banco do Brasil S/A  Real   483258.0
# 3  Agência de Fomento do Estado de Santa Catarina...  Real  2300000.0
# 4       Banco de Desenvolvimento de Minas Gerais S/A  Real   700000.0
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 0                 0                      0  21/05/2012
# 1                 0                      0  22/06/2007
# 2                 0                      0  22/12/2004
# 3                 1                      0  05/07/2012
# 4                 1                      0  23/06/2010

# %%
# 1) Seu código aqui
response = requests.get(url)
data = response.json()
df = pd.DataFrame(data['items'])
df_rj = df[df['interessado'] == 'Rio de Janeiro']
print(df_rj)
# Out:
#       id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 42         6833           Estado  Rio de Janeiro        33  RJ
# 183       65245        Município  Rio de Janeiro   3304557  RJ
# 226        5918           Estado  Rio de Janeiro        33  RJ
# 331        7129           Estado  Rio de Janeiro        33  RJ
# 360        7525           Estado  Rio de Janeiro        33  RJ
# 606       68813        Município  Rio de Janeiro   3304557  RJ
# 672       68463        Município  Rio de Janeiro   3304557  RJ
# 710        4997           Estado  Rio de Janeiro        33  RJ
# 745       13589        Município  Rio de Janeiro   3304557  RJ
# 1317       5734        Município  Rio de Janeiro   3304557  RJ
# 1391      28489        Município  Rio de Janeiro   3304557  RJ
# 2207      23148        Município  Rio de Janeiro   3304557  RJ
# 2420       7141           Estado  Rio de Janeiro        33  RJ
# 3876      10606           Estado  Rio de Janeiro        33  RJ
# 3899       9898           Estado  Rio de Janeiro        33  RJ
# 3905      20535        Município  Rio de Janeiro   3304557  RJ
# 3972      22594           Estado  Rio de Janeiro        33  RJ
# 4291       8643        Município  Rio de Janeiro   3304557  RJ
# 4740       8050        Município  Rio de Janeiro   3304557  RJ
# 4977      12410           Estado  Rio de Janeiro        33  RJ
#
#                    num_pvl                                             status  \
# 42                    None                                           Deferido
# 183   PVL02.001203/2023-06  Encaminhado à PGFN com manifestação técnica fa...
# 226                   None  Encaminhado à PGFN com manifestação técnica fa...
# 331                   None  Encaminhado à PGFN com manifestação técnica fa...
# 360                   None                                           Deferido
# 606   PVL02.000950/2024-08  Encaminhado à PGFN com manifestação técnica fa...
# 672   PVL02.000745/2024-34  Encaminhado à PGFN com manifestação técnica fa...
# 710                   None                                           Deferido
# 745                   None                                          Arquivado
# 1317                  None                                           Deferido
# 1391  PVL02.000606/2018-62                     Arquivado por decurso de prazo
# 2207  PVL02.000145/2016-66                                           Deferido
# 2420                  None  Encaminhado à PGFN com manifestação técnica fa...
# 3876                  None                                           Deferido
# 3899                  None                                           Deferido
# 3905  00000.000000/2017-88                                           Deferido
# 3972  00000.000000/2031-89                     Arquivado por decurso de prazo
# 4291                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4740                  None                                           Deferido
# 4977                  None  Encaminhado à PGFN com manifestação técnica fa...
#
#               num_processo        data_protocolo  \
# 42    17944.000440/2008-75  2008-04-11T03:00:00Z
# 183   17944.102641/2023-45  2023-07-26T13:58:05Z
# 226   17944.000233/2012-05  2012-04-16T03:00:00Z
# 331   17944.000504/2014-86  2014-04-02T03:00:00Z
# 360   17944.000599/2009-71  2009-06-17T03:00:00Z
# 606   17944.003012/2024-14  2024-06-05T21:51:39Z
# 672   17944.001955/2024-11  2024-06-06T14:49:09Z
# 710   17944.000020/2010-11  2010-04-19T03:00:00Z
# 745   19405.000031/2006-30  2006-07-18T03:00:00Z
# 1317  17944.000185/2010-85  2010-10-18T02:00:00Z
# 1391  17944.104407/2018-95  2018-09-04T14:13:17Z
# 2207  17944.001004/2016-23  2016-08-25T03:00:00Z
# 2420  17944.000506/2014-75  2014-04-02T03:00:00Z
# 3876  17944.001240/2009-11  2009-10-22T02:00:00Z
# 3899  17944.001076/2010-85  2011-05-25T03:00:00Z
# 3905  17944.001114/2015-12  2015-12-15T02:00:00Z
# 3972  17944.000657/2016-95  2016-05-12T03:00:00Z
# 4291  17944.000816/2009-22  2011-11-17T02:00:00Z
# 4740  17944.000703/2010-61  2011-04-29T03:00:00Z
# 4977  17944.001680/2011-92  2012-04-16T03:00:00Z
#
#                                           tipo_operacao  \
# 42                          Operação contratual interna
# 183   Operação contratual interna (com garantia da U...
# 226   Operação contratual externa (com garantia da U...
# 331   Operação contratual interna (com garantia da U...
# 360                         Operação contratual interna
# 606   Operação contratual interna (com garantia da U...
# 672   Operação contratual interna (com garantia da U...
# 710                         Operação contratual interna
# 745                         Operação contratual interna
# 1317                        Operação contratual interna
# 1391                        Operação contratual interna
# 2207                        Operação contratual interna
# 2420  Operação contratual interna (com garantia da U...
# 3876                        Operação contratual interna
# 3899                        Operação contratual interna
# 3905                        Operação contratual interna
# 3972  Operação contratual interna (com garantia da U...
# 4291  Operação contratual externa (com garantia da U...
# 4740                        Operação contratual interna
# 4977  Operação contratual externa (com garantia da U...
#
#                                           finalidade  \
# 42                                    Multissetorial
# 183                                   Pró-Transporte
# 226                                   Infraestrutura
# 331                                   Infraestrutura
# 360                          PAC - Saneamento - 2008
# 606                                   Infraestrutura
# 672                                   Pró-Transporte
# 710                                             PMAE
# 745                                Saneamento básico
# 1317                       PAC - Copa Pró-Transporte
# 1391                         Renegociação de dívidas
# 2207                                  Infraestrutura
# 2420                     Desenvolvimento sustentável
# 3876  Aquisição de máquinas, equipamentos e veículos
# 3899                                           Saúde
# 3905                                  Infraestrutura
# 3972                                  Infraestrutura
# 4291                                  Infraestrutura
# 4740                                           PNAFM
# 4977                                  Infraestrutura
#
#                                tipo_credor  \
# 42         Instituição Financeira Nacional
# 183        Instituição Financeira Nacional
# 226   Instituição Financeira Internacional
# 331        Instituição Financeira Nacional
# 360        Instituição Financeira Nacional
# 606        Instituição Financeira Nacional
# 672        Instituição Financeira Nacional
# 710        Instituição Financeira Nacional
# 745        Instituição Financeira Nacional
# 1317       Instituição Financeira Nacional
# 1391       Instituição Financeira Nacional
# 2207       Instituição Financeira Nacional
# 2420       Instituição Financeira Nacional
# 3876       Instituição Financeira Nacional
# 3899       Instituição Financeira Nacional
# 3905       Instituição Financeira Nacional
# 3972       Instituição Financeira Nacional
# 4291  Instituição Financeira Internacional
# 4740       Instituição Financeira Nacional
# 4977  Instituição Financeira Internacional
#
#                                                  credor          moeda  \
# 42    Banco Nacional de Desenvolvimento Econômico e ...           Real
# 183                             Caixa Econômica Federal           Real
# 226                        Corporação Andina de Fomento  Dólar dos EUA
# 331                              Banco BTG Pactual S.A.           Real
# 360                             Caixa Econômica Federal           Real
# 606                                 Banco do Brasil S/A           Real
# 672                             Caixa Econômica Federal           Real
# 710   Banco Nacional de Desenvolvimento Econômico e ...           Real
# 745                             Caixa Econômica Federal           Real
# 1317  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 1391                            Caixa Econômica Federal           Real
# 2207  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 2420  Banco de Investimentos Credit Suisse (Brasil) ...           Real
# 3876                                Banco do Brasil S/A           Real
# 3899                                Banco do Brasil S/A           Real
# 3905  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 3972  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4291            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 4740                            Caixa Econômica Federal           Real
# 4977  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 42    1.500000e+07                 1                      0  18/04/2008
# 183   6.459310e+08                 0                      1  03/08/2023
# 226   3.196750e+08                 1                      0  11/03/2016
# 331   4.500000e+08                 1                      0  01/09/2014
# 360   5.580000e+08                 1                      0  18/06/2009
# 606   9.500000e+08                 0                      1  12/06/2024
# 672   1.414309e+08                 0                      0  12/06/2024
# 710   9.982000e+06                 1                      0  20/04/2010
# 745   4.681860e+05                 0                      0  26/06/2007
# 1317  1.179000e+09                 1                      0  01/12/2010
# 1391  4.416492e+08                 0                      0  22/10/2019
# 2207  8.000000e+08                 1                      0  14/09/2016
# 2420  6.000000e+08                 1                      0  01/09/2014
# 3876  2.000000e+07                 1                      0  04/11/2009
# 3899  1.328000e+08                 0                      0  07/06/2011
# 3905  8.000000e+08                 1                      0  23/12/2015
# 3972  9.892104e+08                 0                      0  25/10/2016
# 4291  1.500000e+08                 1                      0  23/12/2011
# 4740  4.900000e+07                 1                      0  06/06/2011
# 4977  6.000000e+08                 1                      0  10/07/2012

# %%
# 2) Seu código aqui
status_counts = df['status'].value_counts()
print(status_counts.head(3))
# Out:
# status
# Deferido             2492
# Deferido (PVL-IF)    1212
# Arquivado             391
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
df['data_status'] = pd.to_datetime(df['data_status'], format='%d/%m/%Y')

df['ano_status'] = df['data_status'].dt.year

# %%
# 4. Indique a frequência de cada ano do campo construído no item (3)
ano_counts = df['ano_status'].value_counts()
print(ano_counts)
# Out:
# ano_status
# 2008    421
# 2019    397
# 2023    377
# 2022    337
# 2018    288
# 2007    275
# 2012    258
# 2014    244
# 2010    238
# 2024    219
# 2013    216
# 2011    200
# 2021    200
# 2020    192
# 2006    188
# 2009    181
# 2017    170
# 2004    142
# 2015    128
# 2016    128
# 2002     91
# 2003     71
# 2005     39
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
import pandas as pd
import requests

def filtro_uf_tipo(uf, tipo_interessado):
    response = requests.get('https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl')
    data = response.json()
    df = pd.DataFrame(data['items'])

    #filtro
    filtro = (df['uf'] == uf) & (df['tipo_interessado'] == tipo_interessado)
    df_filtrado = df[filtro]
    return df_filtrado

# %%
# 2) Seu código aqui

uf ='MG'
tipo_interessado = 'Estado'

df_mg = filtro_uf_tipo(uf, tipo_interessado)
df_arquivado = df_mg[df_mg['status'] == 'Arquivado por decurso de prazo']
df_arquivado
# Out:
#       id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 3904      20534           Estado  Minas Gerais        31  MG
#
#                    num_pvl                          status  \
# 3904  00000.000000/2017-69  Arquivado por decurso de prazo
#
#               num_processo        data_protocolo                tipo_operacao  \
# 3904  17944.001113/2015-60  2017-07-26T03:00:00Z  Operação contratual interna
#
#      finalidade                      tipo_credor  \
# 3904       PMAE  Instituição Financeira Nacional
#
#                                                  credor moeda      valor  \
# 3904  Banco Nacional de Desenvolvimento Econômico e ...  Real  7668000.0
#
#       pvl_assoc_divida  pvl_contradado_credor data_status
# 3904                 0                      0  16/03/2018

# %%
uf = 'BA'
tipo_interessado = 'Município'

df_ba = filtro_uf_tipo(uf, tipo_interessado)
deferidas_ba = df_ba[df_ba['status'] == 'Deferido']
municipio_mais_deferidas = deferidas_ba['interessado'].value_counts().idxmax()

print(f"Município da Bahia com mais solicitações deferidas: {municipio_mais_deferidas}")
# Out:
# Município da Bahia com mais solicitações deferidas: Luís Eduardo Magalhães

# %%
# 4) Seu código aqui

df_estado_ba = filtro_uf_tipo('BA', 'Estado')
df_estado_ba.to_csv('solicitacoes_bahia_estado.csv', index=False)

print("Arquivo CSV salvo com sucesso.")
# Out:
# Arquivo CSV salvo com sucesso.
